# %%
import n2

from astropy.units import deg
from astropy.units import arcmin
from astropy.units import km
from astropy.units import s

# %matplotlib inline
import matplotlib.pyplot
# Out:
# [19:17:16,910] INFO: python 3.6.5
# [19:17:16,911] INFO: n2-tools 0.0.9

# %%
# using FUGIN data
# see https://nro-fugin.github.io/
#  ! caution !  file size is too large 1.24 GB
d = n2.open_fits('http://jvo.nao.ac.jp/skynode/do/download/nobeyama/fugin/fugin_meta/FGN00000036')
# Out:
# [19:17:16,930] INFO: (open_fits) path=http://jvo.nao.ac.jp/skynode/do/download/nobeyama/fugin/fugin_meta/FGN00000036, hdu_num=0

# %%
d2 = d.cut_world(x=(15.4*deg, 14.8*deg), y=(-0.9*deg, -0.4*deg), z=(0*km/s, 30*km/s))
# Out:
# [19:17:16,970] INFO: (cache.open) .n2cache/b6ceaf4bb0a79c583fd4101032067838faca9c14

# %%
d3 = d2.velocity_binning_pix(3)
# Out:
# [19:21:40,449] INFO: (velocity_binning_pix) width=3
# [19:21:40,450] INFO: (velocity_binning_pix) start calculation
# [19:21:40,551] INFO: (velocity_binning_pix) done
# [19:21:40,577] INFO: (cache.save) .n2cache/52aaef26596df705621f6a49140be446c225f613

# %%
nx = d3.header['NAXIS1']
ny = d3.header['NAXIS2']

fig, ax = n2.plot.subplots(nx, ny, 3, 3, projection=d3.wcs2)
im = [_a.imshow(_d, vmin=0, vmax=50) for _a, _d in zip(ax, d3.data[17:17+27:3])]
[_a.coords[0].set_axislabel('Galactic Lontitude (deg)') for _a in ax]
[_a.coords[0].set_major_formatter('d') for _a in ax]
[_a.coords[0].set_ticks(spacing=1*deg, color='w', size=8) for _a in ax]
[_a.coords[0].display_minor_ticks(True) for _a in ax]
[_a.coords[1].set_axislabel('Galactic Latitude (deg)') for _a in ax]
[_a.coords[1].set_major_formatter('d') for _a in ax]
[_a.coords[1].set_ticks(spacing=1*deg, color='w', size=8) for _a in ax]
[_a.coords[1].display_minor_ticks(True) for _a in ax]
[_a.coords.frame.set_color('w')  for _a in ax]
# Out:
# [None, None, None, None, None, None, None, None, None]
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0xb170360d0> (for post_execute):
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     147             def post_execute():
#     148                 if matplotlib.is_interactive():
# --> 149                     draw_all()
#     150
#     151             # IPython >= 2
#
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     134         for f_mgr in cls.get_all_fig_managers():
#     135             if force or f_mgr.canvas.figure.stale:
# --> 136                 f_mgr.canvas.draw_idle()
#     137
#     138 atexit.register(Gcf.destroy_all)
#
# ...
